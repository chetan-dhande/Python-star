# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from sklearn.datasets import load_boston
boston = load_boston()

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
bos = pd.DataFrame(boston['data'])

# %%
y=pd.DataFrame(boston['target'])

# %%
y['target']=y

# %%
y=y.drop([0],axis=1)

# %%
bos.shape
# Out:
# (506, 13)

# %%
bos.columns=boston['feature_names']

# %%
X=bos

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
bos.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
bos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
bos.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
       'TAX', 'PTRATIO', 'B', 'LSTAT'
# Out:
#   File "<ipython-input-62-b38a5b1e8e97>", line 2
#     'TAX', 'PTRATIO', 'B', 'LSTAT'
#     ^
# IndentationError: unexpected indent

# %%
bost = pd.concat([bos, y], axis=1)

# %%
bost.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
corr = bost.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_a0e6326f_fe71_11ea_92c1_a0d37a303ea9row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# [36.45948839]
# [[-1.08011358e-01  4.64204584e-02  2.05586264e-02  2.68673382e+00
#   -1.77666112e+01  3.80986521e+00  6.92224640e-04 -1.47556685e+00
#    3.06049479e-01 -1.23345939e-02 -9.52747232e-01  9.31168327e-03
#   -5.24758378e-01]]

# %%
lm = smf.ols(formula='target ~ CRIM +ZN+INDUS+CHAS+NOX+RM+AGE+DIS+RAD+TAX+PTRATIO+B+LSTAT', data=bost).fit()
lm.conf_int()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Thu, 24 Sep 2020   Prob (F-statistic):          6.72e-135
# Time:                        20:04:44   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.4595      5.103      7.144      0.000      26.432      46.487
# ...

# %%
lm = smf.ols(formula='target ~ CRIM +ZN+CHAS+NOX+RM+DIS+RAD+TAX+PTRATIO+B+LSTAT', data=bost).fit()
lm.rsquared
# Out:
# 0.7405822802569575

# %%
lm = smf.ols(formula='target ~ CRIM +ZN+INDUS+CHAS+NOX+RM+AGE+DIS+RAD+TAX+PTRATIO+B+LSTAT', data=bost).fit()
lm.rsquared
# Out:
# 0.7406426641094095

# %%
X = bost.drop(["target"],axis=1)
y = bost.target

# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def adj_r2(x,y):
    r2 = regression.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in bost:
    if plotnumber<=16 :
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(bost[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Rahul\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=15 :
        ax = plt.subplot(5,3,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Target',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
scaler =StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = X_scaled

# %%
vif = pd.DataFrame()

# %%
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]

# %%
vif["Features"] = X.columns

# %%
vif
# Out:
#          VIF Features
# 0   1.792192     CRIM
# 1   2.298758       ZN
# 2   3.991596    INDUS
# 3   1.073995     CHAS
# 4   4.393720      NOX
# 5   1.933744       RM
# 6   3.100826      AGE
# 7   3.955945      DIS
# 8   7.484496      RAD
# 9   9.008554      TAX
# 10  1.799084  PTRATIO
# 11  1.348521        B
# 12  2.941491    LSTAT

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(X)

# %%
df=pd.DataFrame(data=X, columns= X.columns)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(df)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %%
pca = PCA(n_components=4)
new_data = pca.fit_transform(df)

principal_Df = pd.DataFrame(data = new_data
             , columns = ['PC 1','PC 2','PC 3','PC 4'])

# %%
principal_Df
# Out:
#            PC 1       PC 2       PC 3       PC 4
# 0   -119.818843  -5.560056  -3.172693   5.291593
# 1   -168.890155  10.116209 -30.781887   1.296776
# 2   -169.311707  14.080532 -16.753628 -10.278399
# 3   -190.230642  18.302463  -6.534195 -19.644921
# 4   -190.133451  16.097947 -13.158520 -14.178141
# ..          ...        ...        ...        ...
# 501 -138.697933   5.781485 -20.978012  -5.706647
# 502 -139.504439   1.039389 -26.794150  -0.878985
# 503 -138.387163   0.938092 -37.285181   8.073690
# 504 -137.505173   4.251825 -35.988342   7.016434
# 505 -139.190333   1.009064 -29.772432   1.676860
#
# [506 rows x 4 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.30,random_state=355)

# %%
y_train
# Out:
# 100    27.5
# 17     17.5
# 140    14.0
# 40     34.9
# 184    26.4
#        ...
# 291    37.3
# 501    22.4
# 346    17.2
# 130    19.2
# 254    21.9
# Name: target, Length: 354, dtype: float64

# %%
regression = LinearRegression()

regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.score(x_train,y_train)
# Out:
# 0.720080795063849

# %%
adj_r2(x_train,y_train)
# Out:
# 0.7093780019339373

# %%
regression.score(x_test,y_test)
# Out:
# 0.7633693372971141

# %%
adj_r2(x_test,y_test)
# Out:
# 0.7410780429845234

# %%
lasscv = LassoCV(alphas = None,cv =10, max_iter = 100000, normalize = True)
lasscv.fit(x_train, y_train)
# Out:
# LassoCV(cv=10, max_iter=100000, normalize=True)

# %%
alpha = lasscv.alpha_
alpha
# Out:
# 0.0003440087272348562

# %%
lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.0003440087272348562)

# %%
lasso_reg.score(x_test, y_test)
# Out:
# 0.7633209795558036

# %%
alphas = np.random.uniform(low=0, high=10, size=(50,))
ridgecv = RidgeCV(alphas = alphas,cv=10,normalize = True)
ridgecv.fit(x_train, y_train)
# Out:
# RidgeCV(alphas=array([6.50629697, 2.47973349, 1.04650534, 7.39045001, 2.28380654,
#        0.11269762, 1.62467167, 6.00105188, 9.34945731, 3.55420806,
#        5.45095363, 1.39283294, 1.18268165, 7.47822405, 6.71823894,
#        0.20461538, 3.1067593 , 6.07661403, 3.49445976, 3.36137067,
#        5.9494274 , 4.13771777, 8.77392177, 5.63302158, 3.16762155,
#        8.06522593, 5.76586726, 4.21410422, 5.29889998, 4.19176868,
#        0.76124023, 6.5245182 , 3.11586789, 7.72456886, 8.64529955,
#        2.21758397, 9.4708971 , 3.14143397, 6.91215334, 5.34191079,
#        8.1935416 , 5.15336161, 8.73908867, 0.65354232, 8.78598049,
#        5.92887828, 3.63608411, 3.47273866, 6.11766144, 5.32576087]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.20461537752969883

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.20461537752969883)

# %%
ridge_model.score(x_test, y_test)
# Out:
# 0.7616281830398638

# %%
elasticCV = ElasticNetCV(alphas = None, cv =10)

elasticCV.fit(x_train, y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elasticCV.alpha_
# Out:
# 1.3825767499760606

# %%
elasticCV.l1_ratio
# Out:
# 0.5

# %%
elasticnet_reg = ElasticNet(alpha = elasticCV.alpha_,l1_ratio=0.5)
elasticnet_reg.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1.3825767499760606)

# %%
elasticnet_reg.score(x_test, y_test)
# Out:
# 0.7163184908767666
